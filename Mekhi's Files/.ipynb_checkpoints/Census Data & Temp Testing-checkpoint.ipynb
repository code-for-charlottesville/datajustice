# %% [markdown]
# # Temporary Testing Notebook

# %%
from sqlalchemy import create_engine
import psycopg2 as db
import pandas as pd
import numpy as np
import os

# %%
postPass = os.environ["POSTGRES_PASS"]

# %%
engine = create_engine("postgresql+psycopg2://{user}:{pw}@localhost/{db}"
                      .format(user="jupyter", pw=postPass, db="expunge"))

# %% [markdown]
# Code below used to get data for census table

# %%
url = "https://demographics.coopercenter.org/sites/demographics/files/media/files/2020-07/Census_2019_RaceEstimates_forVA_0.xls"
demo = pd.read_excel(url, skiprows = 4)
demo = demo.rename({'Unnamed: 4':'white_prop', 'Unnamed: 6':'afam_prop', 'Unnamed: 8':'asian_prop', 'Unnamed: 10':'other_prop', 'Unnamed: 12':'twoplus_prop'}, axis = 1)
demo = demo.loc[~demo['FIPS'].isna()]

# %%
url = "https://demographics.coopercenter.org/sites/demographics/files/media/files/2020-07/Census_2019_HispanicEstimates_forVA_0.xls"
hisp = pd.read_excel(url, skiprows = 4)
hisp = hisp.loc[~hisp['FIPS'].isna()]
hisp = hisp[['FIPS', "Unnamed: 6", "Unnamed: 7"]]
hisp = hisp.rename({'Unnamed: 6': 'hisp_pop', 'Unnamed: 7':'hisp_prop'}, axis = 1)
hisp = hisp.astype('int')

# %%
census = pd.merge(demo, hisp, on='FIPS',
                  how = 'outer',
                  validate = 'one_to_one',
                  indicator = 'matched') 
census.to_sql('census', con = engine, index = False, if_exists='replace')

# %%
census
# Out:
#       FIPS         Jurisdiction  Total Population  White Alone  white_prop  \
# 0      1.0      Accomack County           32316.0      21899.0    0.677652
# 1      3.0     Albemarle County          109330.0      89388.0    0.817598
# 2      5.0     Alleghany County           14860.0      13783.0    0.927524
# 3      7.0        Amelia County           13145.0      10050.0    0.764549
# 4      9.0       Amherst County           31605.0      24299.0    0.768834
# ..     ...                  ...               ...          ...         ...
# 128  800.0         Suffolk city           92108.0      47993.0    0.521051
# 129  810.0  Virginia Beach city          449974.0     303182.0    0.673777
# 130  820.0      Waynesboro city           22630.0      18265.0    0.807114
# 131  830.0    Williamsburg city           14954.0      11013.0    0.736458
# 132  840.0      Winchester city           28078.0      22862.0    0.814232
#
#      African American Alone  afam_prop  Asian Alone  asian_prop  \
# 0                    9304.0   0.287907        257.0    0.007953
# 1                   10600.0   0.096954       6051.0    0.055346
# 2                     698.0   0.046972         46.0    0.003096
# 3                    2688.0   0.204488         80.0    0.006086
# 4                    6041.0   0.191141        180.0    0.005695
# ..                      ...        ...          ...         ...
# 128                 39246.0   0.426087       1754.0    0.019043
# 129                 91161.0   0.202592      33241.0    0.073873
# 130                  3040.0   0.134335        382.0    0.016880
# 131                  2391.0   0.159890        904.0    0.060452
# 132                  3174.0   0.113042        764.0    0.027210
#
#      Other Races Alone  other_prop  Two or more races  twoplus_prop  hisp_pop  \
# 0                293.0    0.009067              563.0      0.017422      2955
# 1                483.0    0.004418             2808.0      0.025684      6313
# 2                 56.0    0.003769              277.0      0.018641       238
# 3                 85.0    0.006466              242.0      0.018410       418
# 4                305.0    0.009650              780.0      0.024680       767
# ..                 ...         ...                ...           ...       ...
# 128              475.0    0.005157             2640.0      0.028662      4300
# 129             2907.0    0.006460            19483.0      0.043298     38235
# 130              149.0    0.006584              794.0      0.035086      1966
# 131              104.0    0.006955              542.0      0.036244      1069
# 132              279.0    0.009937              999.0      0.035579      5127
#
#      hisp_prop matched
# 0            0    both
# 1            0    both
# 2            0    both
# 3            0    both
# 4            0    both
# ..         ...     ...
# 128          0    both
# 129          0    both
# 130          0    both
# 131          0    both
# 132          0    both
#
# [133 rows x 16 columns]
